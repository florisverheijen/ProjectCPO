# %% [markdown]
# # CODE COURSE - Tutorial Principal component analysis - Answers.
# ---

# %% [markdown]
# <div class="alert alert-info" role="alert" style="height:10px;padding:0px;margin-bottom:-20px"></div>
#
# ### PCA with Python  - Answers
#
# <div class="alert alert-info" role="alert" style="height:10px;padding:0px;margin-top:5px;"></div>

# %% [markdown]
# #### Step 0: Importation and preparation of the dataset.

# %%
from sklearn.datasets import load_breast_cancer
load_breast_cancer
# Out:
# <function sklearn.datasets.base.load_breast_cancer>

# %%
breast_data = load_breast_cancer().data

# %%
breast_labels = load_breast_cancer().target

# %%
features = load_breast_cancer().feature_names
features
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='<U23')

# %%
import numpy as np
import pandas as pd

# %%
labels = np.reshape(breast_labels,(569,1))

# %%
final_breast_data = np.concatenate([breast_data,labels], axis=1)
final_breast_data
# Out:
# array([[  1.79900000e+01,   1.03800000e+01,   1.22800000e+02, ...,
#           4.60100000e-01,   1.18900000e-01,   0.00000000e+00],
#        [  2.05700000e+01,   1.77700000e+01,   1.32900000e+02, ...,
#           2.75000000e-01,   8.90200000e-02,   0.00000000e+00],
#        [  1.96900000e+01,   2.12500000e+01,   1.30000000e+02, ...,
#           3.61300000e-01,   8.75800000e-02,   0.00000000e+00],
#        ...,
#        [  1.66000000e+01,   2.80800000e+01,   1.08300000e+02, ...,
#           2.21800000e-01,   7.82000000e-02,   0.00000000e+00],
#        [  2.06000000e+01,   2.93300000e+01,   1.40100000e+02, ...,
#           4.08700000e-01,   1.24000000e-01,   0.00000000e+00],
#        [  7.76000000e+00,   2.45400000e+01,   4.79200000e+01, ...,
#           2.87100000e-01,   7.03900000e-02,   1.00000000e+00]])

# %%
breast_dataset = pd.DataFrame(final_breast_data)
breast_dataset.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9  ...      21      22      23      24      25      26      27  \
# 0  0.07871 ...   17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667 ...   23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999 ...   25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744 ...   26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883 ...   16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29   30
# 0  0.4601  0.11890  0.0
# 1  0.2750  0.08902  0.0
# ...

# %%
features_labels = np.append(features,'label')

# %%
breast_dataset.columns = features_labels

# %%
breast_dataset.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...    worst texture  worst perimeter  worst area  \
# ...

# %%
breast_dataset['label'].replace(0, 'Benign',inplace=True)
breast_dataset['label'].replace(1, 'Malignant',inplace=True)
breast_dataset.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension   ...    worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# Now the dataset is ready to get started with PCA.

# %% [markdown]
# #### Step 1: Standarization
#
# 1) Use the command code StandardScaler and fit_transform to write a code that can calculate the standardization of the whole data, except the kolom lable.
#
# **Answer:**

# %%
from sklearn.preprocessing import StandardScaler

X = breast_dataset.loc[:, features].values # code to get the values of all # python basis
#the data expect the data of the labels.
X = StandardScaler().fit_transform(X) # normalizing the features # nieuw in PCA
X
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %% [markdown]
# 2) Let's check whether the normalized data has a mean of zero and a standard deviation of one.
#
# **Answer:**

# %%
np.mean(X),np.std(X)
# Out:
# (-6.8265382931843257e-17, 1.0)

# %% [markdown]
# 3) Write below a code that shows the new data table with the normalizations.
#
# **Answer:**

# %%
#feat_cols = ['feature'+str(i) for i in range(x.shape[1])]
normalised_breast = pd.DataFrame(X,columns=features)
#normalised_breast = pd.DataFrame(x,columns=feat_cols)
normalised_breast.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564          0.219060        1.947285             2.320965      -0.312589
# 565         -0.017833        0.693043             1.263669      -0.217664
# 566         -0.038680        0.046588             0.105777      -0.809117
# 567          3.272144        3.296944             2.658866       2.137194
# 568         -1.150752       -1.114873            -1.261820      -0.820070
#
#      mean fractal dimension           ...             worst radius  \
# ...

# %% [markdown]
# #### Step 2: Calculation of the covariance matrix

# %% [markdown]
# 4) Calculate the Covariance-matrix using the command *cov*
#
# **Answer:**

# %%
cov_mat = np.cov(X.T) 
cov_mat
#print('NumPy covariance matrix: \n%s' %np.cov(X.T))
# Out:
# array([[  1.00176056e+00,   3.24351929e-01,   9.99612069e-01,
#           9.89095475e-01,   1.70881506e-01,   5.07014640e-01,
#           6.77955036e-01,   8.23976636e-01,   1.48001350e-01,
#          -3.12179472e-01,   6.80285970e-01,  -9.74887767e-02,
#           6.75358538e-01,   7.37159198e-01,  -2.22992026e-01,
#           2.06362656e-01,   1.94545531e-01,   3.76831225e-01,
#          -1.04504545e-01,  -4.27163418e-02,   9.71245907e-01,
#           2.97530545e-01,   9.66835698e-01,   9.42739295e-01,
#           1.19826732e-01,   4.14190751e-01,   5.27839123e-01,
#           7.45524434e-01,   1.64241985e-01,   7.07832563e-03],
#        [  3.24351929e-01,   1.00176056e+00,   3.30113223e-01,
#           3.21650988e-01,  -2.34296930e-02,   2.37118951e-01,
#           3.02950254e-01,   2.93980713e-01,   7.15266864e-02,
#          -7.65717560e-02,   2.76354360e-01,   3.87037830e-01,
#           2.82169018e-01,   2.60302460e-01,   6.62542133e-03,
# ...

# %% [markdown]
# #### Step 3 Calculation of the Eigenvalues and Eigenvectoren
#
# 5) Calculate the Eigenvalues and Eigenvectoren<br>
# **Answer:**<br>
# with *eig_vals, eig_vecs = np.linalg.eig(cov_mat)*

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

eig_vecs
# Out:
# array([[  2.18902444e-01,  -2.33857132e-01,  -8.53124284e-03,
#           4.14089623e-02,  -3.77863538e-02,   1.87407904e-02,
#           1.24088340e-01,   7.45229622e-03,  -2.23109764e-01,
#           9.54864432e-02,   4.14714866e-02,   5.10674568e-02,
#           1.19672116e-02,  -5.95061348e-02,   5.11187749e-02,
#          -1.50583883e-01,   2.02924255e-01,   1.46712338e-01,
#           2.25384659e-01,   7.02414091e-01,  -2.11460455e-01,
#           2.11194013e-01,   1.31526670e-01,  -1.29476396e-01,
#          -1.92264989e-02,   1.82579441e-01,  -9.85526942e-02,
#           7.29289034e-02,   4.96986642e-02,   6.85700057e-02],
#        [  1.03724578e-01,  -5.97060883e-02,   6.45499033e-02,
#          -6.03050001e-01,   4.94688505e-02,  -3.21788366e-02,
#          -1.13995382e-02,  -1.30674825e-01,   1.12699390e-01,
#           2.40934066e-01,  -3.02243402e-01,   2.54896423e-01,
#           2.03461333e-01,   2.15600995e-02,   1.07922421e-01,
# ...

# %% [markdown]
# #### Step 4: Determining the most important principal component

# %% [markdown]
# 6) make a eig_pairs list of (eigenvalue, eigenvector) tulples and print the Eigenvalues in descending order.<br>
# **Short answer:**<br>
# with make a list of tulples<br>
# .sort<br>
# .reverse<br>
# print Eigenvalues in descending order<br>
# **Long answer:**<br>

# %%
#selecting principal components


# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
#eig_pairs.sort(key=lambda x: x[0], reverse=True)
# or
eig_pairs.sort() # python
eig_pairs.reverse() # python


# Visually confirm that the list is correctly sorted by decreasing eigenvalues
#print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# 13.3049907944
# 5.70137460373
# 2.82291015501
# 1.98412751773
# 1.65163324233
# 1.2094822398
# 0.676408881701
# 0.47745625469
# 0.417628782108
# 0.351310874882
# 0.294433153491
# 0.261621161366
# 0.241782421328
# 0.157286149218
# 0.0943006956011
# 0.0800034044774
# 0.0595036135304
# 0.0527114222101
# 0.049564700213
# 0.0312142605531
# 0.0300256630904
# 0.0274877113389
# 0.0243836913546
# 0.0180867939843
# 0.0155085271344
# 0.00819203711761
# 0.00691261257918
# 0.0015921360012
# 0.000750121412719
# 0.000133279056664

# %% [markdown]
# #### Step 5: Calculation of the explained variance
#
# 7.1) Calculate the totale varaince of the eigenvalues.<br>
# **Answer:**

# %%
tot = sum(eig_vals)

# %% [markdown]
# 7.2) Calculate the explained variance (var_exp) <br>
# **Answer:**

# %%
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)] # percentage berekenen van elke PC

# %% [markdown]
# 7.3) Calculate the Cummulative explained variance (cum_var_exp)<br>
# **Answer:**

# %%
cum_var_exp = np.cumsum(var_exp)

# %% [markdown]
# #### Step 6 Cummulative plot of the principal components.

# %% [markdown]
# 8) Make in one plot a bar graph of the individual explained variance and a step graph of the cumulative explained variance.<br>
# **Answer:**

# %%
plt.figure(figsize=(6, 4))
plt.bar(range(30), var_exp, alpha=0.5, align='center',
         label='individual explained variance')
plt.step(range(30), cum_var_exp, where='mid',
         label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# 9) Make a scree plot. <br>
# **Answer**

# %%
fig = plt.figure(figsize=(8,5))
plt.plot(var_exp, 'o-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
 
leg = plt.legend(['Eigenvalues'])
plt.show()

# %% [markdown]
# #### Step 7: Reducing the dimensions

# %% [markdown]
# 10) Reshape the eig_pair data in matrix_w with only the Eigenvectors of the two highest eigenvalues. *hint: use hstack*<br>
# **Answer:**

# %%
 
matrix_w = np.hstack((eig_pairs[0][1].reshape(30,1),
                      eig_pairs[1][1].reshape(30,1)))

print('Matrix W:\n', matrix_w)
# Out:
# Matrix W:
#  [[ 0.21890244 -0.23385713]
#  [ 0.10372458 -0.05970609]
#  [ 0.22753729 -0.21518136]
#  [ 0.22099499 -0.23107671]
#  [ 0.14258969  0.18611302]
#  [ 0.23928535  0.15189161]
#  [ 0.25840048  0.06016536]
#  [ 0.26085376 -0.0347675 ]
#  [ 0.13816696  0.19034877]
#  [ 0.06436335  0.36657547]
#  [ 0.20597878 -0.10555215]
#  [ 0.01742803  0.08997968]
#  [ 0.21132592 -0.08945723]
#  [ 0.20286964 -0.15229263]
#  [ 0.01453145  0.20443045]
#  [ 0.17039345  0.2327159 ]
#  [ 0.15358979  0.19720728]
#  [ 0.1834174   0.13032156]
#  [ 0.04249842  0.183848  ]
#  [ 0.10256832  0.28009203]
#  [ 0.22799663 -0.21986638]
#  [ 0.10446933 -0.0454673 ]
#  [ 0.23663968 -0.19987843]
#  [ 0.22487053 -0.21935186]
#  [ 0.12795256  0.17230435]
#  [ 0.21009588  0.14359317]
#  [ 0.22876753  0.09796411]
#  [ 0.25088597 -0.00825724]
#  [ 0.12290456  0.14188335]
#  [ 0.13178394  0.27533947]]

# %% [markdown]
# 11) calculate the inner product of X and matrix_w and name it **Y**<br>
# **Answer:**

# %%
Y = X.dot(matrix_w)

# %% [markdown]
# #### Step 8: Plotting the data

# %% [markdown]
# 12) Make a scatter plot that display the data of bennign in red and maligant in green with the plottitle *Principal Component Analysis of Breast Cancer Dataset*,<br> x axis Principal Component 1, y axis Principal Component 2 and legend.<br>
# **Answer:**

# %%
from matplotlib import pyplot as plt
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of Breast Cancer Dataset",fontsize=20)
targets = ['Benign', 'Malignant']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = breast_dataset['label'] == target
    plt.scatter(Y[indicesToKeep,0]
               , Y[indicesToKeep,1], c = color, s = 50)

plt.legend(targets,prop={'size': 15})
plt.show()

# %% [markdown]
# #### Step 9: Interpretation of the data

# %% [markdown]
# 13) Give a interpretation of the data that is present in the scatter plot in exercise 11. <br>
# **Answer:**

# %% [markdown]
# The clusters are different based on PC1. The loading plot was not possible so it is unclear which variables have influenced this differences. Furthmore, the malignant cells show less spread than the benign cells. So, the variables of the malignant cells have more similar values than the benign cell values.
