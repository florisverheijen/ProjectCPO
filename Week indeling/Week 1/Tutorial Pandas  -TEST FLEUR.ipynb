# %% [markdown]
# # Pandas tutorial
#
# In this tutorial you will learn the basics about using Pandas in Python.
# Pandas is a library in Python, which can be used to manipulate and analyse data easier. You can read more about pandas on their [website](https://pandas.pydata.org/).
#
# For additional content, you can visit the following sites:
#
# - [Python: Pandas Tutorial | Intro to DataFrames - YouTube](https://www.youtube.com/watch?v=e60ItwlZTKM).
# - [Datacamp - Pandas Tutorial](https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python).
# - [Leanr Python - Pandas Basics](https://www.learnpython.org/en/Pandas_Basics).

# %% [markdown]
# ## Contents of the tutorial
#
# 1. Import library
# 2. DataFrames
#     * Concept
#     * Commands
#     * See the data
# 3. Series
#     * Concept
#     * Commands
#     * See the data
# 4. Import datafile
#     * CSV
#     * Matlab
# 5. Statistics
# 6. Sorting and grouping a Dataframe
# 7. Adding a column by calculation
# 8. Delete data for optimisation
# 9. Working with NaN values
# 10. Plotting a DataFrame

# %% [markdown]
# ______________________

# %% [markdown]
# ## 1. Import library
#
# To work with pandas, the first thing that needs to be done is importing the library. It can be done in the cell below.

# %%
import pandas as pd

# %% [markdown]
# ____________________

# %% [markdown]
# ## 2. DataFrame
#
# A DataFrame is a table just like the one you probably know from excel. It contains rows and columns for example this is a small DataFrame:

# %%
pd.DataFrame({'Yes':[50,21], 'No':[131,20]})
# Out:
#     No  Yes
# 0  131   50
# 1   20   21

# %% [markdown]
# You can see that the rows have the values 0 and 1 these indexes can be changed if you prefer it to other numbers or even to strings.
# The code you need for this is located in the cell below test it and see what happens. <span style="color:red"> Ik zou deze zin even beter verwoorden. een punt na below zal al voldoende zijn</span>

# %%
pd.DataFrame({'Yes':[50,21], 'No':[131,20]},index = ['Product A','Product B'])
# Out:
#            Yes   No
# Product A   50  131
# Product B   21   20

# %% [markdown]
# _______________________

# %% [markdown]
# ## 3. Series
#
# Pandas also has something that is called series. A Series is a sequence of data values. A Series is like a list if a DataFrame is a table. To create one you just need some data values; <span style="color:red">duidelijker verwoorden</span>

# %%
pd.Series([5,6,7,8])
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %% [markdown]
# ___________________

# %% [markdown]
# ## 4. Import data files
#
# Creating a DataFrame or Series is nice to do but the power of Pandas comes from the reading data that is already available for <span style="color:red">from?</span>a csv file <span style="color:red"> punt </span>this can simply be done by using the `read_csv()` function from Pandas.
#
# In biomedical engineering sometimes the dataset we want to read is stored in a matlab file with the .mat extention <span style="color:red">hier vermeld je het maar het wordt zometeen weer herhaald. dus dit is naar mijn mening wat overbodig. ook staat hier .mat. zometeen gebruik je geen .mat meer. wat is de juiste manier?</span>

# %%
movies=pd.read_csv("Movies.csv")
movies#.head() # this shows the first 5 rows of the DataFrame
# Out:
#                                                   title  year  lifetime_gross  \
# 0                                            METROPOLIS  1928         1236166
# 1                                           CITY LIGHTS  1931           19181
# 2                                          MODERN TIMES  1936          163577
# 3                                    GONE WITH THE WIND  1939       198676459
# 4                                      THE WIZARD OF OZ  1939        22342633
# 3732      0      0         0         1    0        0          NaN
# 3733      0      0         0         0    0        0          NaN
# 3734      0      0         0         0    0        0          NaN
# 3735      0      0         0         0    0        0          NaN
# 3736      0      0         0         0    0        0          NaN
# 3737      0      0         0         0    0        0          NaN
# 3738      0      0         0         0    0        0          NaN
# 3739      0      0         0         1    0        0          NaN
# 3740      0      0         0         0    0        0          NaN
# 3741      0      0         0         0    0        0          NaN
# 3742      0      0         0         1    0        0          NaN
# 3743      0      1         0         0    0        0          NaN
# 3744      0      0         0         0    0        0          NaN
# 3745      0      0         0         0    0        0          NaN
# 3746      0      0         0         0    0        0          NaN
# 3747      0      0         0         0    0        0          NaN
# 3748      0      0         0         0    0        0          NaN
# 3749      0      0         0         0    0        0          NaN
#
# [3750 rows x 38 columns]

# %% [markdown]
# The movie with the highest ratingCount can be found by using : <span style="color:red"> De vraag is welke film de hoogste ratingcount heeft. nu haal je de hoogste ratingcount eruit, maar je weet niet welke film erbij hoort</span>

# %%
mostrating = movies['ratingCount'].max()
mostrating
# Out:
# 1183395

# %% [markdown]
# A lot of courses in BME use Matlab. To import a matlab file, loadmat from scipy.io is needed. Below an example can be seen.

# %%
## Import the right library
from scipy.io import loadmat

## use loadmat to import
mat = loadmat( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fd62c933fd27> in <module>()
#       3
#       4 ## use loadmat to import
# ----> 5 mat = loadmat( )
#
# TypeError: loadmat() missing 1 required positional argument: 'file_name'

# %% [markdown]
# _________________________

# %% [markdown]
# ## 5. Statistics
#
# Statistics are also very important when working with datasets. In this section various functions will be discussed and used to find out some more about the dataset.
#
# On your cheat sheet you can find several functions in the section statistics. For example:
# `df.count()`: returns the number of values.
#
# In the next cell, try it out for the number of nominations. <span style="color:red">het precieze woord nominations staat niet in de tabel. express gedaan? uiteindelijk heb ik het makkelijk gevonden. </span>

# %%
## TRY OUT: find the number of nominations
movies['nrOfNominations'].count()
# Out:
# 3750

# %% [markdown]
# ALso the function `df.describe()` can be very useful to get an overview of your data. Try it out below. The argument `include='all'` can be used for the summary statistics of all columns. <span style="color:red"> als ik include all invul krijg ik juist meer rijen, dus ik snap niet helemaal waarom het een summary zou moeten geven,</span>

# %%
## TRY OUT: get an overview of your data.
movies.describe()
# Out:
#        lifetime_gross  ratingInteger   ratingCount      duration     nrOfWins  \
# count    3.750000e+03   3.750000e+03  3.750000e+03   3750.000000  3750.000000
# mean     4.843950e+07   4.108937e+04  7.090083e+04   6637.528533     9.002933
# std      6.395942e+07   1.984213e+06  1.016313e+05   1425.411253   156.172762
# min      4.230000e+02   2.000000e+00  5.000000e+00   2760.000000     0.000000
# 25%      8.400621e+06   6.000000e+00  1.307225e+04   5760.000000     0.000000
# 50%      2.780892e+07   7.000000e+00  3.583150e+04   6360.000000     1.000000
# 75%      6.138347e+07   7.000000e+00  8.568975e+04   7200.000000     5.000000
# max      7.605076e+08   1.151040e+08  1.183395e+06  38274.000000  6780.000000
#
#        nrOfNominations   nrOfPhotos  nrOfNewsArticles  nrOfUserReviews  \
# count      3750.000000  3750.000000       3750.000000      3750.000000
# mean          7.546400    45.349600        595.921600       275.146133
# std          13.171129    39.408587       1436.690163       369.126777
# min           0.000000     0.000000          0.000000         0.000000
# 25%           0.000000    19.000000         42.000000        76.000000
# 50%           3.000000    35.000000        154.000000       159.000000
# 75%           9.000000    59.000000        547.000000       324.750000
# max         137.000000   394.000000      23660.000000      4928.000000
#
#          nrOfGenre     ...       RealityTV      Romance        SciFi  \
# count  3750.000000     ...          3750.0  3750.000000  3750.000000
# mean      2.584000     ...             0.0     0.174933     0.085333
# std       2.392698     ...             0.0     0.379961     0.279414
# min       0.000000     ...             0.0     0.000000     0.000000
# 25%       2.000000     ...             0.0     0.000000     0.000000
# 50%       3.000000     ...             0.0     0.000000     0.000000
# 75%       3.000000     ...             0.0     0.000000     0.000000
# max     106.000000     ...             0.0     1.000000     1.000000
#
#              Short        Sport  TalkShow     Thriller          War  \
# count  3750.000000  3750.000000    3750.0  3750.000000  3750.000000
# mean      0.000267     0.033867       0.0     0.162933     0.022133
# std       0.016330     0.180910       0.0     0.369354     0.147137
# min       0.000000     0.000000       0.0     0.000000     0.000000
# 25%       0.000000     0.000000       0.0     0.000000     0.000000
# 50%       0.000000     0.000000       0.0     0.000000     0.000000
# 75%       0.000000     0.000000       0.0     0.000000     0.000000
# max       1.000000     1.000000       0.0     1.000000     1.000000
#
#            Western  Unnamed: 37
# count  3750.000000          2.0
# mean      0.009333          0.0
# std       0.096170          0.0
# min       0.000000          0.0
# 25%       0.000000          0.0
# 50%       0.000000          0.0
# 75%       0.000000          0.0
# max       1.000000          0.0
#
# [8 rows x 36 columns]

# %%
movies.describe(include='all')
# Out:
#                  title  year  lifetime_gross  ratingInteger   ratingCount  \
# count             3750  3750    3.750000e+03   3.750000e+03  3.750000e+03
# unique            3713    80             NaN            NaN           NaN
# top     THE KARATE KID  2006             NaN            NaN           NaN
# freq                 4   161             NaN            NaN           NaN
# mean               NaN   NaN    4.843950e+07   4.108937e+04  7.090083e+04
# std                NaN   NaN    6.395942e+07   1.984213e+06  1.016313e+05
# min                NaN   NaN    4.230000e+02   2.000000e+00  5.000000e+00
# 25%                NaN   NaN    8.400621e+06   6.000000e+00  1.307225e+04
# 50%                NaN   NaN    2.780892e+07   7.000000e+00  3.583150e+04
# 75%                NaN   NaN    6.138347e+07   7.000000e+00  8.568975e+04
# max                NaN   NaN    7.605076e+08   1.151040e+08  1.183395e+06
#
#             duration     nrOfWins  nrOfNominations   nrOfPhotos  \
# count    3750.000000  3750.000000      3750.000000  3750.000000
# unique           NaN          NaN              NaN          NaN
# top              NaN          NaN              NaN          NaN
# freq             NaN          NaN              NaN          NaN
# mean     6637.528533     9.002933         7.546400    45.349600
# std      1425.411253   156.172762        13.171129    39.408587
# min      2760.000000     0.000000         0.000000     0.000000
# 25%      5760.000000     0.000000         0.000000    19.000000
# 50%      6360.000000     1.000000         3.000000    35.000000
# 75%      7200.000000     5.000000         9.000000    59.000000
# max     38274.000000  6780.000000       137.000000   394.000000
#
#         nrOfNewsArticles     ...       RealityTV      Romance        SciFi  \
# count        3750.000000     ...          3750.0  3750.000000  3750.000000
# unique               NaN     ...             NaN          NaN          NaN
# top                  NaN     ...             NaN          NaN          NaN
# freq                 NaN     ...             NaN          NaN          NaN
# mean          595.921600     ...             0.0     0.174933     0.085333
# std          1436.690163     ...             0.0     0.379961     0.279414
# min             0.000000     ...             0.0     0.000000     0.000000
# 25%            42.000000     ...             0.0     0.000000     0.000000
# 50%           154.000000     ...             0.0     0.000000     0.000000
# 75%           547.000000     ...             0.0     0.000000     0.000000
# max         23660.000000     ...             0.0     1.000000     1.000000
#
#               Short        Sport  TalkShow     Thriller          War  \
# count   3750.000000  3750.000000    3750.0  3750.000000  3750.000000
# unique          NaN          NaN       NaN          NaN          NaN
# top             NaN          NaN       NaN          NaN          NaN
# freq            NaN          NaN       NaN          NaN          NaN
# mean       0.000267     0.033867       0.0     0.162933     0.022133
# std        0.016330     0.180910       0.0     0.369354     0.147137
# min        0.000000     0.000000       0.0     0.000000     0.000000
# 25%        0.000000     0.000000       0.0     0.000000     0.000000
# 50%        0.000000     0.000000       0.0     0.000000     0.000000
# 75%        0.000000     0.000000       0.0     0.000000     0.000000
# max        1.000000     1.000000       0.0     1.000000     1.000000
#
#             Western  Unnamed: 37
# count   3750.000000          2.0
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean       0.009333          0.0
# std        0.096170          0.0
# min        0.000000          0.0
# 25%        0.000000          0.0
# 50%        0.000000          0.0
# 75%        0.000000          0.0
# max        1.000000          0.0
#
# [11 rows x 38 columns]

# %% [markdown]
# ____________________________

# %% [markdown]
# ## 6. Sorting and grouping a DataFrame
#
# When using data, it can be very useful to sort the data according to a certain value. Sorting the DataFrame can be done by: `df.sort_values(by = column)`. Additionally, the argument `ascending=False` can be added, to sort the values in descending order. The index of the dataframe can also be reset, by using the argument `.reset_index()`.
#
# In the next cell, try it out for the number of news articles. <span style="color:red"> ik kwam niet echt uit het deel 'by = column', maar op internet snel gevonden</span>

# %%
## TRY OUT: sort the dataframe by number of news articles

# %%
movies.sort_values(by=['nrOfNewsArticles'], ascending=False).head()
# Out:
#                       title  year  lifetime_gross  ratingInteger  ratingCount  \
# 35                STAR WARS  1977       460998007              9       631839
# 1657               IRON MAN  2008       318412101              8       476288
# 133   THE DARK KNIGHT RISES  2012       448139099              9       758626
# 1863                   THOR  2011       181030624              7       346716
# 115         THE DARK KNIGHT  2008       534858444              9      1148515
#
#       duration  nrOfWins  nrOfNominations  nrOfPhotos  nrOfNewsArticles  \
# 35        7260        35               26         190             23660
# 1657      7560        15               43         155             22252
# 133       9900        28               64         131             22240
# 1863      6900         5               15         134             17429
# 115       9120        94               69         107             17229
#
#          ...       RealityTV  Romance  SciFi  Short  Sport  TalkShow  \
# 35       ...               0        0      0      0      0         0
# 1657     ...               0        0      1      0      0         0
# 133      ...               0        0      0      0      0         0
# 1863     ...               0        0      0      0      0         0
# 29        0      0         0         1    0        0          NaN
# ...     ...    ...       ...       ...  ...      ...          ...
# 3720      0      0         0         0    0        0          NaN
# 3721      0      0         0         0    0        0          NaN
# 3722      0      0         0         0    0        0          NaN
# 3723      0      0         0         1    0        0          NaN
# 3724      0      0         0         0    0        0          NaN
# 3725      0      0         0         0    0        0          NaN
# 3726      0      0         0         0    0        0          NaN
# 3727      0      0         0         0    0        0          NaN
# 3728      0      0         0         0    0        0          NaN
# 3729      0      0         0         0    0        0          NaN
# 3730      0      0         0         1    0        0          NaN
# 3731      0      0         0         0    0        0          NaN
# 3732      0      0         0         1    0        0          NaN
# 3733      0      0         0         0    0        0          NaN
# 3734      0      0         0         0    0        0          NaN
# 3735      0      0         0         0    0        0          NaN
# 3736      0      0         0         0    0        0          NaN
# 3737      0      0         0         0    0        0          NaN
# 3738      0      0         0         0    0        0          NaN
# 3739      0      0         0         1    0        0          NaN
# 3740      0      0         0         0    0        0          NaN
# 3741      0      0         0         0    0        0          NaN
# 3742      0      0         0         1    0        0          NaN
# 3743      0      1         0         0    0        0          NaN
# 3744      0      0         0         0    0        0          NaN
# 3745      0      0         0         0    0        0          NaN
# 3746      0      0         0         0    0        0          NaN
# 3747      0      0         0         0    0        0          NaN
# 3748      0      0         0         0    0        0          NaN
# 3749      0      0         0         0    0        0          NaN
#
# [3750 rows x 39 columns]

# %% [markdown]
# The rows in a DataFrame can also be grouped. This can be done by using `df.groupby()`. Try it out below for genre. <span style="color:red"> hier kom ik niet uit. ik kan de precieze benaming van de kolom niet vinden in de dataframe </span>

# %%
## TRY OUT: group the data by genre.
movies.groupby(['genre'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-859883e11e81> in <module>()
#       1 ## TRY OUT: group the data by genre.
# ----> 2 movies.groupby(['genre'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4269         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4270                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4271                        **kwargs)
#    4272
#    4273     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1624         raise TypeError('invalid type: %s' % type(obj))
#    1625
# -> 1626     return klass(obj, by, **kwds)
#    1627
#    1628
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2615                 in_axis, name, level, gpr = False, None, gpr, None
#    2616             else:
# -> 2617                 raise KeyError(gpr)
#    2618         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2619             # Add key to exclusions
#
# KeyError: 'genre'

# %% [markdown]
# ___________________________

# %% [markdown]
# ## 7. Adding a column by calculation
#
# New values can also be calculated from the dataframe. This can be done by naming the new colum, followed by the calculation. An example can be seen below.

# %%
movies['NoWinNominations'] = movies['nrOfWins']-movies['nrOfNominations']
movies
# Out:
#                                                   title  year  lifetime_gross  \
# 0                                            METROPOLIS  1928         1236166
# 1                                           CITY LIGHTS  1931           19181
# 3727      0         0         0    0        0          NaN                 0
# 3728      0         0         0    0        0          NaN                 0
# 3729      0         0         0    0        0          NaN                 0
# 3730      0         0         1    0        0          NaN                 0
# 3731      0         0         0    0        0          NaN                 0
# 3732      0         0         1    0        0          NaN                 0
# 3733      0         0         0    0        0          NaN                 0
# 3734      0         0         0    0        0          NaN                 0
# 3735      0         0         0    0        0          NaN                -1
# 3736      0         0         0    0        0          NaN                 0
# 3737      0         0         0    0        0          NaN                 0
# 3738      0         0         0    0        0          NaN                 0
# 3739      0         0         1    0        0          NaN                 0
# 3740      0         0         0    0        0          NaN                 0
# 3741      0         0         0    0        0          NaN                 0
# 3742      0         0         1    0        0          NaN                -1
# 3743      1         0         0    0        0          NaN                 0
# 3744      0         0         0    0        0          NaN                 0
# 3745      0         0         0    0        0          NaN                21
# 3746      0         0         0    0        0          NaN                 2
# 3747      0         0         0    0        0          NaN                 0
# 3748      0         0         0    0        0          NaN                 0
# 3749      0         0         0    0        0          NaN                -2
#
# [3750 rows x 39 columns]

# %% [markdown]
# ________________

# %% [markdown]
# ## 8. Delete data for optimization
#
# When a dataframe is very big, there are often a lot of values that are unnessecary in your research. To this extent, these values can be deleted. This can be done by the function `df.drop()`. It can be done for one row, several rows, one column and several columns.
#
# In the cell below, try it out for the number of photos by creating a new DataFrame. <span style="color:red"> Gelukt met internet </span>

# %%
## TRY OUT: drop the column of number of photos by creating a new DataFrame.
movies.drop(['nrOfPhotos'], axis=1)
# Out:
#                                                   title  year  lifetime_gross  \
# 0                                            METROPOLIS  1928         1236166
# 1                                           CITY LIGHTS  1931           19181
# 2                                          MODERN TIMES  1936          163577
# 3                                    GONE WITH THE WIND  1939       198676459
# 4                                      THE WIZARD OF OZ  1939        22342633
# 5                                          CITIZEN KANE  1941         1585634
# 6                                            CASABLANCA  1942         4108411
# 7                           THE BEST YEARS OF OUR LIVES  1946        23650000
# 8                                         THE THIRD MAN  1949          618173
# 9                                         ALL ABOUT EVE  1950           63463
# 10                                  SINGIN' IN THE RAIN  1952         1826108
# 11                                    DIAL M FOR MURDER  1954           12562
# 12                                          REAR WINDOW  1954        36764313
# 13                         THE BRIDGE ON THE RIVER KWAI  1957        27200000
# 14                                        TOUCH OF EVIL  1958         2247465
# 15                                              VERTIGO  1958         7311013
# 16                                              BEN-HUR  1959        74000000
# 17                                               PSYCHO  1960        32000000
# 18                                   LAWRENCE OF ARABIA  1962        44824144
# 19    DR. STRANGELOVE OR: HOW I LEARNED TO STOP WORR...  1964         9440272
# 20                      WHO'S AFRAID OF VIRGINIA WOOLF?  1966        28000000
# 21                                         THE GRADUATE  1967       104945305
# 22                                2001: A SPACE ODYSSEY  1968        58588800
# 23                   BUTCH CASSIDY AND THE SUNDANCE KID  1969       102308889
# 24                                        THE GODFATHER  1972       134966411
# 25                                            THE STING  1973       156000000
# 26                                            CHINATOWN  1974        29200000
# 27                               THE GODFATHER: PART II  1974        47542841
# 28                                    DOG DAY AFTERNOON  1975        50000000
# 3731              5         7654      4860         0                0
# 3732              6        56085      6480         0                0
# 3733              5        11807      5940         0                0
# 3734              5          558      5400         0                0
# 3735              8        17063      5040         3                4
# 3736              6        47641      6600         0                0
# 3737              8        10458      5520         0                0
# 3738              7        44253      5400         0                0
# 3739              6       113423      6480         0                0
# 3740              8        75813      7440         0                0
# 3741              6        39017      6720         0                0
# 3742              6        40433      5520         1                2
# 3743              6        34283      6600         0                0
# 3744              7        48137      5520         0                0
# 3745              8        56014      6000        27                6
# 3746              5         1328      5460         3                1
# 3747              5        57934      5640         0                0
# 3748              7         1250      7560         0                0
# 3749              5         3913      5760         1                3
#
#       nrOfNewsArticles  nrOfUserReviews        ...         Romance  SciFi  \
# 0                  428              376        ...               0      1
# 1                  187              186        ...               1      0
# 2                   27              180        ...               0      0
# 3                 1263              653        ...               1      0
# 4                 2363              477        ...               0      0
# 5                 1439             1101        ...               0      0
# 6                  382              960        ...               1      0
# 7                  129              218        ...               1      0
# 8                  338              364        ...               0      0
# 9                  253              276        ...               0      0
# 10                 333              441        ...               1      0
# 11                 232              223        ...               0      0
# 12                 711              580        ...               0      0
# 13                 160              243        ...               0      0
# 14                 211              245        ...               0      0
# 15                 671              618        ...               1      0
# 16                 193              340        ...               0      0
# 17                2059              885        ...               0      0
# 18                 929              509        ...               0      0
# 19                 432              782        ...               0      0
# 20                  10              213        ...               0      0
# 21                 329              573        ...               1      0
# 22                  28             1568        ...               0      1
# 23                 508              281        ...               0      0
# 24                1307             1751        ...               0      0
# 25                 275              224        ...               0      0
# 26                 547              412        ...               0      0
# 27                 197              565        ...               0      0
# 28                 438              228        ...               0      0
# 29                1497              880        ...               0      0
# ...                ...              ...        ...             ...    ...
# 3720               602              815        ...               0      0
# 3721               284              256        ...               1      0
# 3722               142               52        ...               0      0
# 3723              1357              308        ...               0      0
# 3724                 9               54        ...               0      0
# 3725                 0               10        ...               0      0
# 3726               278               99        ...               0      0
# 3727               184              180        ...               0      0
# 3728              1122              201        ...               0      0
# 3729                 0               16        ...               1      0
# 3730               197              373        ...               0      0
# 3731               212               44        ...               0      0
# 3732               450              386        ...               0      1
# 3733                83              158        ...               0      0
# 3734                 4                9        ...               1      0
# 3735               177              228        ...               0      0
# 3736               166              173        ...               0      0
# 3737                 0              153        ...               0      0
# 3738               487               57        ...               0      0
# 3739               287              600        ...               0      0
# 3740               115              221        ...               0      0
# 3741               843              143        ...               1      0
# 3742               596              181        ...               0      0
# 3743               268               80        ...               0      0
# 3744                93              190        ...               0      0
# 3745               756              499        ...               0      0
# 3746                 7               20        ...               0      0
# 3747               232              371        ...               0      0
# 3748                 0               13        ...               0      0
# 3749                13               50        ...               0      0
#
#       Short  Sport  TalkShow  Thriller  War  Western  Unnamed: 37  \
# 0         0      0         0         0    0        0          NaN
# 1         0      0         0         0    0        0          NaN
# 2         0      0         0         0    0        0          NaN
# 3         0      0         0         0    1        0          NaN
# 4         0      0         0         0    0        0          NaN
# 5         0      0         0         0    0        0          NaN
# 6         0      0         0         0    1        0          NaN
# 7         0      0         0         0    1        0          NaN
# 8         0      0         0         1    0        0          NaN
# 9         0      0         0         0    0        0          NaN
# 10        0      0         0         0    0        0          NaN
# 11        0      0         0         1    0        0          NaN
# 12        0      0         0         1    0        0          NaN
# 13        0      0         0         0    1        0          NaN
# 14        0      0         0         1    0        0          NaN
# 15        0      0         0         1    0        0          NaN
# 16        0      0         0         0    0        0          NaN
# 17        0      0         0         1    0        0          NaN
# 18        0      0         0         0    0        0          NaN
# 19        0      0         0         0    1        0          NaN
# 20        0      0         0         0    0        0          NaN
# 21        0      0         0         0    0        0          NaN
# 22        0      0         0         0    0        0          NaN
# 23        0      0         0         0    0        0          NaN
# 24        0      0         0         0    0        0          NaN
# 25        0      0         0         0    0        0          NaN
# 26        0      0         0         1    0        0          NaN
# 27        0      0         0         0    0        0          NaN
# 28        0      0         0         0    0        0          NaN
# 29        0      0         0         1    0        0          NaN
# ...     ...    ...       ...       ...  ...      ...          ...
# 3720      0      0         0         0    0        0          NaN
# 3721      0      0         0         0    0        0          NaN
# 3722      0      0         0         0    0        0          NaN
# 3723      0      0         0         1    0        0          NaN
# 3724      0      0         0         0    0        0          NaN
# 3725      0      0         0         0    0        0          NaN
# 3726      0      0         0         0    0        0          NaN
# 3727      0      0         0         0    0        0          NaN
# 3728      0      0         0         0    0        0          NaN
# 3729      0      0         0         0    0        0          NaN
# 3730      0      0         0         1    0        0          NaN
# 3731      0      0         0         0    0        0          NaN
# 3732      0      0         0         1    0        0          NaN
# 3733      0      0         0         0    0        0          NaN
# 3734      0      0         0         0    0        0          NaN
# 3735      0      0         0         0    0        0          NaN
# 3736      0      0         0         0    0        0          NaN
# 3737      0      0         0         0    0        0          NaN
# 3738      0      0         0         0    0        0          NaN
# 3739      0      0         0         1    0        0          NaN
# 3740      0      0         0         0    0        0          NaN
# 3741      0      0         0         0    0        0          NaN
# 3742      0      0         0         1    0        0          NaN
# 3743      0      1         0         0    0        0          NaN
# 3744      0      0         0         0    0        0          NaN
# 3745      0      0         0         0    0        0          NaN
# 3746      0      0         0         0    0        0          NaN
# 3747      0      0         0         0    0        0          NaN
# 3748      0      0         0         0    0        0          NaN
# 3749      0      0         0         0    0        0          NaN
#
#       NoWinNominations
# 0                   -1
# 1                    2
# 2                    2
# 3                    4
# 4                   -6
# 5                   -3
# 6                   -1
# 7                   12
# 8                   -1
# 9                    0
# 10                  -3
# 11                   1
# 12                   0
# 13                  19
# 14                   2
# 15                   3
# 16                  15
# 17                   1
# 18                   7
# 19                   9
# 20                   2
# 21                   7
# 22                   6
# 23                   6
# 24                  10
# 25                   4
# 26                  -2
# 27                  -5
# 28                  -4
# 29                  -5
# ...                ...
# 3720                 7
# 3721                -2
# 3722                -5
# 3723               -11
# 3724                 0
# 3725                 0
# 3726                 0
# 3727                 0
# 3728                 0
# 3729                 0
# 3730                 0
# 3731                 0
# 3732                 0
# 3733                 0
# 3734                 0
# 3735                -1
# 3736                 0
# 3737                 0
# 3738                 0
# 3739                 0
# 3740                 0
# 3741                 0
# 3742                -1
# 3743                 0
# 3744                 0
# 3745                21
# 3746                 2
# 3747                 0
# 3748                 0
# 3749                -2
#
# [3750 rows x 38 columns]

# %% [markdown]
# _________________

# %% [markdown]
# ## 9. Working with NaN values
#
# There are often values which are 'NaN'. This means that this value is missing. There are several options in this case. You can give these a values, for example 0 or 1. Or these values can be dropped.
#
# To drop these values: `df.dropna()`. When the argument `how='any'` is used, the row is dropped when any value is missing. When the argument `how='all'` is used, the row is dropped when all values are misisng. Try it out below

# %%
## TRY OUT: make a new DataFrame where there are no NaN values.
movies.dropna(how='any')
# Out:
#                title       year  lifetime_gross  ratingInteger  ratingCount  \
# 2694  THE KARATE KID    PART II            1986      115103979            6
# 2811  THE KARATE KID   PART III            1989       38956288            5
#
#       duration  nrOfWins  nrOfNominations  nrOfPhotos  nrOfNewsArticles  \
# 2694     38274      6780                4           2                20
# 2811     24938      6720                0           0                12
#
#             ...         Romance  SciFi  Short  Sport  TalkShow  Thriller  War  \
# 2694        ...               0      1      0      0         0         0    0
# 2811        ...               0      0      0      0         0         0    0
#
#       Western  Unnamed: 37  NoWinNominations
# 2694        0          0.0              6776
# 2811        0          0.0              6720
#
# [2 rows x 39 columns]

# %% [markdown]
# To replace the missing values the function, the function `df.fillna()` can be used. Try this out for the title below by creating a new DataDrame. <span style="color:red"> Ik snap niet wat hier de bedoeling is </span>

# %%
## TRY OUT: make a new DataFrame with NaN values changed for title.
movies.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-28e9109e9665> in <module>()
#       1 ## TRY OUT: make a new DataFrame with NaN values changed for title.
# ----> 2 movies.fillna()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    2850                      self).fillna(value=value, method=method, axis=axis,
#    2851                                   inplace=inplace, limit=limit,
# -> 2852                                   downcast=downcast, **kwargs)
#    2853
#    2854     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    3470         if value is None:
#    3471             if method is None:
# -> 3472                 raise ValueError('must specify a fill method or value')
#    3473             if self._is_mixed_type and axis == 1:
#    3474                 if inplace:
#
# ValueError: must specify a fill method or value

# %% [markdown]
# ________________________

# %% [markdown]
# ## 10. Plotting DataFrame
#
# Plotting can give useful insight on your Dataframe. Here we will learn you the basics of plotting.
# First of all, matplotlib and Seaborn need to be imported. This has already been set for you in the cell below. Also, to make plots appear in your notebook, a line is added.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# The general function for plotting is: `df.plot(kind='...',...)`.
# Different kinds can be used, such as:
#
# * line: also the default setting.
# * area: area is filled under the line.
# * bar: vertical barchart.
# * barh: horizontal barchart.
# * hist: histogram. With argument `bins=n`, the number of bins can be adjusted.
# * box: boxplot. With argument `by=...`, it will be grouped by given columns.
# * density: densityplot.
# * scatter: scatterplot.

# %% [markdown]
# Next, make some plots for yourself.

# %%
## TRY OUT: make several plots of the movies DataFrame.
movies.plot(['ratingCount'],['ratingInteger'],kind='scatter', )
